# %%
import pandas

# %%
data_csv = pandas.read_csv('Tweets.csv')

# %%
data_csv[data_csv.airline == "Delta"]
# Out:
#            tweet_id airline_sentiment  airline_sentiment_confidence  \
# 6746   5.703093e+17          positive                        0.6469
# 6747   5.703093e+17           neutral                        0.6869
# 6748   5.703085e+17           neutral                        1.0000
# 6749   5.703078e+17          negative                        1.0000
# 6750   5.703054e+17          negative                        1.0000
# ...             ...               ...                           ...
# 8963   5.676673e+17           neutral                        1.0000
# 8964   5.675900e+17          negative                        1.0000
# 8965   5.675883e+17           neutral                        1.0000
# 12038  5.702945e+17          negative                        1.0000
# 12039  5.687577e+17          negative                        0.7991
#
#                     negativereason  negativereason_confidence airline  \
# 6746                           NaN                        NaN   Delta
# ...
